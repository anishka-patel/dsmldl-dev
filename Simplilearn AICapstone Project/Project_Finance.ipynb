# %% [markdown]
# ### AI CAPSTONE PROJECT
# FINANCE (PROJECT 2)
#
# Created on: 09-09-2019
# Author: Anishka V Patel

# %% [markdown]
# <a id='top'></a>

# %% [markdown]
# ### DESCRIPTION
#
# <h4>Problem Statement</h4>
#
# Finance Industry is the biggest consumer of Data Scientists. <br>
# It faces constant attack by fraudsters, who try to trick the system. <br>
# Correctly identifying fraudulent transactions is often compared with <br>
# finding needle in a haystack because of the low event rate.<br>
# It is important that credit card companies are able to recognize <br>
# fraudulent credit card transactions so that the customers are not <br>
# charged for items that they did not purchase.<br>
# You are required to try various techniques such as supervised models <br>
# with oversampling, unsupervised anomaly detection, and heuristics <br>
# to get good accuracy at fraud detection.
# <br>
# <h4>Project Task: Week 1</h4>
# <h5>Exploratory Data Analysis (EDA): <a href='#eda'>Click!</a></h5>
# <ol>
# <li>Perform an EDA on the Dataset.
#     <ol>
#        <li>Check all the latent features and parameters with their <br>
#            mean and standard deviation. Value are close to 0 centered <br>
#            (mean)with unit standard deviation
#        <li>Find if there is any connection between Time, Amount, and <br>
#            the transaction being fraudulent.
#     </ol>
# <li>Check the class count for each class. It’s a class Imbalance problem.
# <li>Use techniques like undersampling or oversampling before running <br>
#     Naïve Bayes, Logistic Regression or SVM.
#     <ol>
#        <li>Oversampling or undersampling can be used to tackle the <br>
#            class imbalance problem
#        <li>Oversampling increases the prior probability of imbalanced <br>
#            class and in case of other classifiers, error gets multiplied <br>
#            as the low-proportionate class is mimicked multiple times.
#            </ol>
# <li>Following are the matrices for evaluating the model performance: <br>
#     Precision, Recall, F1-Score, AUC-ROC curve. Use F1-Score as the <br>
#     evaluation criteria for this project.
# </ol>
# <h4>Project Task: Week 2</h4>
# <h5>Modeling Techniques: <a href='#models'>Click!</a></h5>
# Try out models like Naive Bayes, Logistic Regression or SVM. <br>
# Find out which one performs the best.Use different Tree-based <br>
# classifiers like Random Forest and XGBoost.
#     <ol>
#         <li>Remember Tree-based classifiers work on two <br>
#             ideologies: Bagging or Boosting
#         <li>Tree-based classifiers have fine-tuning parameters <br>
#             which takes care of the imbalanced class. <br>
#             Random-Forest and XGBboost.
#     </ol>
# Compare the results of 1 with 2 and check if there is any incremental gain.
# <br>
# <h4>Project Task: Week 3</h4>
# <ol>
#     <li><h5>Applying ANN: Use ANN (Artificial Neural Network) to predict Store Sales. <a href='#ann'>Click!</a></h5>
#         <ol>
#            <li>Fine-tune number of layers
#            <li>Number of Neurons in each layers
#            <li>Experiment in batch-size
#            <li>Experiment with number of epochs. Check the observations in loss and accuracy
#            <li>Play with different Learning Rate variants of Gradient Descent like <br>
#                Adam, SGD, RMS-prop
#            <li>Find out which activation performs best for this use case and why?
#            <li>Calculate RMSE
#            <li>Check Confusion Matrix, Precision, Recall and F1-Score
#         </ol>
#     <li><h5>Try out Dropout for ANN.</h5>
#         How is it performed? Compare model performance with <br>
#         the traditional ML based prediction models from above.
#     <li><h5>Find the best setting of neural net </h5>
#         that can be best classified as fraudulent <br>
#         and non-fraudulent transactions. Use techniques like <br>
#         Grid Search, Cross-Validation and Random search.
#     <li><h5>Anomaly Detection: Implement anomaly detection algorithms. <a href='#ada'>Click!</a></h5>
#         <ol>
#             <li>Assume that the data is coming from a single or a combination of <br>
#                 multivariate Gaussian
#             <li>Formalize a scoring criterion, which gives a scoring probability <br>
#                 for the given data point whether it belongs to the multivariate <br>
#                 Gaussian or Normal Distribution fitted in a)
#         </ol>
# </ol>
# <h4>Project Task: Week 4</h4>
# <h5>Inference and Observations: <a href='#io'>Click!</a></h5>
# <ol>
#     <li>Visualize the scores for Fraudulent and Non-Fraudulent transactions.
#     <li>Find out the threshold value for marking or reporting a transaction <br>
#         as fraudulent in your anomaly detection system.
#     <li>Can this score be used as an engineered feature in the models developed<br>
#         previously? Are there any incremental gains in F1-Score? Why or Why not?
#     <li>Be as creative as possible in finding other interesting insights.
# <ol>

# %% [markdown]
# <a id='TOC'></a>
# ### Table of Contents
# <ol>
#     <li><a href='#imports'>Imports</a></li>
#     <li><a href='#define_constants'>Define Constants</a></li>
#     <li><a href='#input_steup'>Input file Setup</a></li>
#     <li><a href='#reduce_mem'>Reduce Memory Usage</a></li>
#     <li><a href='#input_df'>Input Dataframe</a></li>
#     <li><a href='#eda'>Exploartory Data Analysis</a></li>
#     <li><a href='#exam'>Examine: Class, Time, Amount Columns</a></li>
#     <li><a href='#upsamp'>Data Upsampling</a></li>
#     <li><a href='#data_treat'>Data Treatment</a></li>
#     <li><a href='#xtract'>Features and Label Extraction</a></li>
#     <li><a href='#preproc'>Preprocessing</a></li>
#     <li><a href='#eval_func'>Evaluation Function</a></li>
#     <li><a href='#models'>Model Training and evaluation:</a></li>
#     <ol>
#         <li><a href='#lr'>Logistic Regression</a></li>
#         <li><a href='#naive'>Gaussian Naive Bayes</a></li>
#         <li><a href='#lda'>Linear Discriminant Analysis</a></li>
#         <li><a href='#svm'>Support Vector Machine</a></li>
#         <li><a href='#rfc'>Random Forest Classifier</a></li>
#         <li><a href='#xgb'>XG Boost Classifier</a></li>
#         <li><a href='#lightgbm'>Light GBM Classifier</a></li>
#         <li><a href='#ann'>Artificial Neural Network</a></li>
#     </ol>
# </ol>

# %% [markdown]
# <a id='imports'></a>
# ### IMPORTS

# %% [markdown]
# <a href='#top'>TOP</a>
# <br>
# <br>
# <a href='#TOC'>Table of Content</a>

# %%
import os
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <a id='define_constants'></a>
# ### DEFINE CONSTANTS

# %% [markdown]
# <a href='#top'>TOP</a>
# <br>
# <br>
# <a href='#TOC'>Table of Content</a>

# %% [markdown]
# <a id='input_setup'></a>
# ### INPUT FILES

# %% [markdown]
# <a href='#top'>TOP</a>
# <br>
# <br>
# <a href='#TOC'>Table of Content</a>

# %%
INPUT_DIR = '../input/Financial'

# %%
files = os.listdir(INPUT_DIR)
files
# Out:
# ['test_data.csv', 'test_data_hidden.csv', 'train_data.csv']

# %%
input_files = {}
for file in files:
    if 'train' in file:
        input_files['train_data'] = INPUT_DIR + '/' + file
    elif 'hidden' in file:
        input_files['test_hidden'] = INPUT_DIR + '/' + file
    else:
        input_files['test_data'] = INPUT_DIR + '/' + file
input_files
# Out:
# {'test_data': '../input/Financial/test_data.csv',
#  'test_hidden': '../input/Financial/test_data_hidden.csv',
#  'train_data': '../input/Financial/train_data.csv'}

# %% [markdown]
# <a id='reduce_mem'></a>
# ### Reduce Memory Usage

# %% [markdown]
# <a href='#top'>TOP</a>
# <br>
# <br>
# <a href='#TOC'>Table of Content</a>

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %% [markdown]
# <a id='input_df'></a>
# ### INPUT DATAFRAMES: Train, Test, Hidden

# %% [markdown]
# <a href='#top'>TOP</a>
# <br>
# <br>
# <a href='#TOC'>Table of Content</a>

# %%
train_df = reduce_mem_usage(pd.read_csv(input_files['train_data']))
train_df.head()
# Out:
# Mem. usage decreased to 13.69 Mb (74.6% reduction)
#        Time        V1        V2        V3        V4        V5        V6  \
# 0   38355.0  1.043945  0.318604  1.045898  2.806641 -0.561035 -0.367920
# 1   22555.0 -1.665039  0.808594  1.805664  1.903320 -0.821777  0.934570
# 2    2431.0 -0.323975  0.602051  0.865234 -2.138672  0.294678 -1.251953
# 3   86773.0 -0.258301  1.217773 -0.585449 -0.875488  1.222656 -0.311035
# 4  127202.0  2.142578 -0.494873 -1.936523 -0.818359 -0.025208 -1.027344
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.032745 -0.042328 -0.322754  ... -0.240112 -0.680176  0.085327  0.684570
# 1 -0.824707  0.976074  1.747070  ... -0.335449 -0.511230  0.035828  0.147583
# 2  1.072266 -0.334961  1.071289  ...  0.012222  0.352783 -0.341553 -0.145752
# 3  1.074219 -0.161377  0.200684  ... -0.424561 -0.781250  0.019318  0.178589
# 4 -0.151611 -0.305664 -0.869629  ...  0.010117  0.021729  0.079468 -0.480957
#
# ...

# %%
test_df = reduce_mem_usage(pd.read_csv(input_files['test_data']))
test_df.head()
# Out:
# Mem. usage decreased to  3.37 Mb (74.2% reduction)
#        Time        V1        V2        V3        V4        V5        V6  \
# 0  113050.0  0.114685  0.796387 -0.149536 -0.823242  0.878906 -0.553223
# 1   26667.0 -0.039307  0.495850 -0.811035  0.546875  1.986328  4.386719
# 2  159519.0  2.275391 -1.531250 -1.021484 -1.602539 -1.220703 -0.462402
# 3  137545.0  1.940430 -0.357666 -1.210938  0.382568  0.050812 -0.171265
# 4   63369.0  1.081055 -0.502441  1.076172 -0.543457 -1.472656 -1.065430
#
#          V7        V8        V9  ...       V20       V21       V22       V23  \
# 0  0.939453 -0.108521  0.111145  ... -0.042725 -0.335693 -0.807617 -0.055939
# 1 -1.344727 -1.744141 -0.562988  ...  0.926270 -1.376953 -0.072205 -0.197632
# 2 -1.196289 -0.147095 -0.950195  ... -0.408203 -0.193237 -0.103516  0.151001
# 3 -0.109131 -0.002115  0.869141  ... -0.199219  0.157959  0.650391  0.034210
# 4 -0.443115 -0.143433  1.660156  ...  0.059875  0.224121  0.821289 -0.137207
#
# ...

# %%
test_hidden_df = reduce_mem_usage(pd.read_csv(input_files['test_hidden']))
test_hidden_df.head()
# Out:
# Mem. usage decreased to  3.42 Mb (74.6% reduction)
#        Time        V1        V2        V3        V4        V5        V6  \
# 0  113050.0  0.114685  0.796387 -0.149536 -0.823242  0.878906 -0.553223
# 1   26667.0 -0.039307  0.495850 -0.811035  0.546875  1.986328  4.386719
# 2  159519.0  2.275391 -1.531250 -1.021484 -1.602539 -1.220703 -0.462402
# 3  137545.0  1.940430 -0.357666 -1.210938  0.382568  0.050812 -0.171265
# 4   63369.0  1.081055 -0.502441  1.076172 -0.543457 -1.472656 -1.065430
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.939453 -0.108521  0.111145  ... -0.335693 -0.807617 -0.055939 -1.025391
# 1 -1.344727 -1.744141 -0.562988  ... -1.376953 -0.072205 -0.197632  1.014648
# 2 -1.196289 -0.147095 -0.950195  ... -0.193237 -0.103516  0.151001 -0.811035
# 3 -0.109131 -0.002115  0.869141  ...  0.157959  0.650391  0.034210  0.739746
# 4 -0.443115 -0.143433  1.660156  ...  0.224121  0.821289 -0.137207  0.986328
#
# ...

# %% [markdown]
# <a id='eda'></a>
# ### EDA: Exploratory Data Analysis

# %% [markdown]
# <a href='#top'>TOP</a>
# <br>
# <br>
# <a href='#TOC'>Table of Content</a>

# %%
def check_null_values(df):
    for column in df.columns:
        print('Column Name:', column, '\nHas null values:',df[column].isna().any(), '\nAmount of null values:', df[column].isna().sum())
        print('Values - Count')
        print(df[column].value_counts())
        print()

# %%
def plot_hist(df):
    plt.figure(figsize=(20, 32))
    for index, column in enumerate(df.columns):
        plt.subplot(8, 4, index+1)
        plt.hist(df[column], color = 'blue', edgecolor = 'black', bins = int(180/5), )
        plt.xlabel(column)
    plt.show()
    plt.savefig('./dump/plot_hist.png')

# %%
def plot_sns_dist(df):
    plt.figure(figsize=(20, 32))
    for index, column in enumerate(df.columns):
        plt.subplot(8, 4, index + 1)
        sns.distplot(df[column])
    plt.savefig('./dump/sns_distplot.png')

# %%
def plot_sns_scatterplot(df):
    plt.figure(figsize=(20, 32))
    for index, column in enumerate(df.drop(columns=['Class']).columns):
        plt.subplot(8, 4, index+1)
        sns.scatterplot(x=column, y='Class', data=df)
    plt.savefig('./dump/sns_scatterplot.png')

# %%
def plot_sns_pairplot(df):
    plt.figure(figsize=(20, 32))
    for index, column in enumerate(df.drop(columns=['Class']).columns):
        plt.subplot(8, 4, index+1)
        sns.scatterplot(x=column, y='Class', data=df)
    plt.savefig('./dump/sns_pairplot.png')

# %%
def replace_null_values(df):
    for column in df.columns:
        if(df[column].isna().any()):
            print(column, df[column].isna().sum())
            def replace():
                global i
                values = df[column].value_counts().index
                counts = df[column].value_counts().values
                counts = counts/counts.sum()
                yield np.random.choice(values,replace=False, p=counts)
            new_value = replace()
            df[column].fillna(value=next(new_value), inplace=True)
    for column in df.columns:
        print(column, df[column].isna().sum())
        if(df[column].isna().any()):
            print('Column:', column, 'has null values')
        else:
            print('No Null values in column')

# %%
def check_mean_sd(df):
    for column in df.columns:
        print('Column Name:', column, '\nHas mean value:',df[column].mean(), '\nHas Standard Deviation:', df[column].std())
        print(df[column].value_counts())
        print()

# %%
plot_hist(train_df)

# %%
plot_sns_scatterplot(train_df)

# %%
plot_sns_dist(train_df)

# %%
fig, ax = plt.subplots(figsize=(40, 40))
sns.heatmap(train_df.corr(), ax=ax, robust=False, annot=True, linewidths=0, cmap='Blues')
plt.savefig('./dump/sns_heatmap.png')

# %%
sns.pairplot(train_df, kind="scatter", hue="Class")
plt.show()
plt.savefig('./dump/sns_pairplot.png')

# %%
desc = train_df.describe()

# %%
for col in desc.columns:
    print(col)
    print('---------------')
    print(desc[col])
    print()
# Out:
# Time
# ---------------
# count    227845.000000
# mean      94752.859375
# std       47500.410156
# min           0.000000
# 25%       54182.000000
# 50%       84607.000000
# 75%      139340.000000
# max      172792.000000
# Name: Time, dtype: float64
#
# V1
# ---------------
# count    227845.000000
# mean         -0.000000
# std           0.000000
# min         -56.406250
# 25%          -0.922852
# 50%           0.012665
# 75%           1.314453
# max           2.455078
# Name: V1, dtype: float64
#
# V2
# ---------------
# count    227845.000000
# mean         -0.000000
# std           0.000000
# min         -72.687500
# 25%          -0.598145
# 50%           0.066650
# 75%           0.804199
# max          22.062500
# Name: V2, dtype: float64
#
# V3
# ---------------
# count    227845.000000
# mean          0.000000
# std           0.000000
# min         -32.968750
# 25%          -0.889160
# 50%           0.182129
# 75%           1.029297
# max           9.382812
# ...

# %% [markdown]
# <a id='exam'></a>
# ### EXAMINATION

# %% [markdown]
# <a href='#top'>TOP</a>
# <br>
# <br>
# <a href='#TOC'>Table of Content</a>

# %%
exam_df = train_df[['Class', 'Amount', 'Time']]
exam_df.head()
# Out:
#    Class    Amount      Time
# 0      0  49.65625   38355.0
# 1      0  16.93750   22555.0
# 2      0   1.00000    2431.0
# 3      0  10.78125   86773.0
# 4      0  39.96875  127202.0

# %%
view_df = exam_df.groupby('Class').get_group(1)
view_df
# Out:
#         Class      Amount      Time
# 266         1   11.382812   41181.0
# 360         1  316.000000   93853.0
# 421         1    0.010002  102572.0
# 734         1    0.000000   53658.0
# 854         1    1.000000    8169.0
# ...       ...         ...       ...
# 226409      1  175.875000  128803.0
# 226814      1  362.500000  129764.0
# 226817      1    1.000000  152098.0
# 226957      1    1.000000   68207.0
# 227531      1    1.000000  149236.0
#
# [394 rows x 3 columns]

# %%
check_null_values(view_df)
# Out:
# Column Name: Class
# Has null values: False
# Amount of null values: 0
# Values - Count
# 1    394
# Name: Class, dtype: int64
#
# Column Name: Amount
# Has null values: False
# Amount of null values: 0
# Values - Count
# 1.000000       90
# 100.000000     21
# 0.000000       17
# 0.759766       16
# 0.770020        8
#                ..
# 153.500000      1
# 1354.000000     1
# 273.000000      1
# 51.375000       1
# 11.382812       1
# Name: Amount, Length: 212, dtype: int64
#
# Column Name: Time
# Has null values: False
# Amount of null values: 0
# Values - Count
# 68207.0    6
# 94362.0    4
# 93853.0    3
# 93879.0    3
# 84204.0    3
#           ..
# 25254.0    1
# 93897.0    1
# 41413.0    1
# 56887.0    1
# 62080.0    1
# Name: Time, Length: 376, dtype: int64

# %%
view_df.shape
# Out:
# (394, 3)

# %%
plt.figure(figsize=(15, 5))
for index, column in enumerate(view_df.columns):
    plt.subplot(1, 3, index+1)
    plt.hist(view_df[column], color = 'blue', edgecolor = 'black', bins = int(180/5), )
    plt.xlabel('Histogram of ' + column + ' column')
plt.show()
plt.savefig('./dump/hist_class_amount_time.png')

# %%
for index, column in enumerate(view_df.columns):
    plt.subplot(1, 3, index+1)
    sns.distplot(view_df[column])
    plt.xlabel(column)
plt.show()
plt.savefig('./dump/sns_dist_plot_class_amount_time.png')

# %%
plt.figure(figsize=(15, 5))
for index, column in enumerate(view_df.columns)
    plt.subplot(1, 3, index+1)
    sns.scatterplot(x=column, y='Class', data=view_df)
plt.savefig('./dump/sns_scatterplot.png')

# %% [markdown]
# <a id='pca'></a>
# ### PRINCIPLE COMPONENT ANALYSIS

# %% [markdown]
# <a href='#top'>TOP</a>
# <br>
# <br>
# <a href='#TOC'>Table of Content</a>

# %%
from sklearn.decompositon import PCA

# %%
pca = PCA(n_component=2)

# %%
train_df_pca = pca.fit_transform(train_df.drop(columns=['Class']))

# %%
pickle.dump(pca, opne('./pca.data', 'wb'))

# %%
pickle.dump(train_df_pca, open('./train_df_pca.data', 'wb'))

# %%
display(train_df_pca)

# %%
train_view['pca_0'] = train_df_pca[:, 0]
train_view['pca_1'] = train_df_pca[:, 1]
display(train_view.head())

# %%
plt.figure(figsize=(32, 32))
sns_plot = sns.scatterplot(x='pca_0', y='pca_1', hue='Class', data=train_view)
fig = sns_plot.get_figure()
fig.savefig("./dump/output-eda-pca.png")
display(sns_plot)

# %% [markdown]
# <a id='pca'></a>
# ### T-DISTRIBUTED STOCHASTIC NEIGHBOUR EMBEDDING

# %% [markdown]
# <a href='#top'>TOP</a>
# <br>
# <br>
# <a href='#TOC'>Table of Content</a>

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(init='random', verbose=1)

# %%
train_df_tsne = tsne.fit_transform(train_df.drop(columns=['Class']))

# %%
pickle.dump(tsne, open('./tsne.data', 'wb'))

# %%
pickle.dump(train_df_tsne, open('./train_df_tsne.data', 'wb'))

# %%
display(train_df_tsne)

# %%
train_view['tsne_0'] = train_df_tsne[:, 0]
train_view['tsne_1'] = train_df_tsne[:, 1]
display(train_view.head())

# %%
plt.figure(figsize=(32, 32))
sns_plot = sns.scatterplot(x='tsne_0', y='tsne_1', hue='Class', data=train_view)
fig = sns_plot.get_figure()
fig.savefig("./dump/output-eda-tsne.png")
display(sns_plot)

# %% [markdown]
# <a id='upsamp'></a>
# ### DATA UPSAMPLING

# %% [markdown]
# <a href='#top'>TOP</a>
# <br>
# <br>
# <a href='#TOC'>Table of Content</a>

# %%
not_fraud = train_df[train_df['Class'] == 0]
fraud = train_df[train_df['Class'] == 1]

print(not_fraud.shape)
print(fraud.shape)
# Out:
# (227451, 31)
# (394, 31)

# %%
from sklearn.utils import resample
fraud_upsampled = resample(fraud,
                          replace=True,
                          n_samples=len(not_fraud),
                          )
print(fraud_upsampled.shape)
# Out:
# (227451, 31)

# %%
train_df = pd.concat([not_fraud, fraud_upsampled])
train_df['Class'].value_counts()
# Out:
# 1    227451
# 0    227451
# Name: Class, dtype: int64

# %%
train_df
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 0        38355.0  1.043945  0.318604  1.045898  2.806641 -0.561035 -0.367920
# 1        22555.0 -1.665039  0.808594  1.805664  1.903320 -0.821777  0.934570
# 2         2431.0 -0.323975  0.602051  0.865234 -2.138672  0.294678 -1.251953
# 3        86773.0 -0.258301  1.217773 -0.585449 -0.875488  1.222656 -0.311035
# 4       127202.0  2.142578 -0.494873 -1.936523 -0.818359 -0.025208 -1.027344
# ...          ...       ...       ...       ...       ...       ...       ...
# 62380   165981.0 -5.765625 -8.398438  0.056549  6.949219  9.882812 -5.773438
# 223988   47826.0 -0.887207  1.389648  1.219727  1.661133  1.008789 -0.733887
# 92556   133958.0  0.523926  1.531250 -4.175781  3.583984 -1.024414 -0.502441
# 92656   125200.0 -0.769043  1.341797 -2.171875 -0.151489 -0.648438 -0.973633
# 30344     7551.0  0.316406  3.808594 -5.613281  6.046875  1.553711 -2.650391
#
# ...

# %% [markdown]
# <a id='data_treat'></a>
# ### DATA TREATMENT

# %% [markdown]
# <a href='#top'>TOP</a>
# <br>
# <br>
# <a href='#TOC'>Table of Content</a>

# %%
check_null_values(train_df)
# Out:
# Column Name: Time
# Has null values: False
# Amount of null values: 0
# Values - Count
# 68207.0     3489
# 94362.0     2388
# 93879.0     1741
# 93853.0     1724
# 93860.0     1722
#             ...
# 69249.0        1
# 78565.0        1
# 71866.0        1
# 163586.0       1
# 112857.0       1
# Name: Time, Length: 113960, dtype: int64
#
# Column Name: V1
# Has null values: False
# Amount of null values: 0
# Values - Count
# -13.195312    3488
# -26.453125    2388
# -12.835938    1755
#  1.140625     1753
#  1.261719     1296
#               ...
# -0.008339        1
# -12.992188       1
#  0.027115        1
# -11.125000       1
#  0.053131        1
# Name: V1, Length: 16390, dtype: int64
#
# Column Name: V2
# Has null values: False
# Amount of null values: 0
# Values - Count
#  12.789062    3488
#  16.500000    2388
#  2.224609     1235
#  2.097656     1228
#  1.133789     1222
#               ...
# -11.265625       1
#  0.050201        1
#  3.886719        1
# -0.028900        1
# ...

# %%
check_null_values(test_df)
# Out:
# Column Name: Time
# Has null values: False
# Amount of null values: 0
# Values - Count
# 64947.0     7
# 163152.0    7
# 68780.0     7
# 142583.0    6
# 60988.0     5
#            ..
# 141363.0    1
# 92436.0     1
# 128025.0    1
# 74404.0     1
# 154020.0    1
# Name: Time, Length: 46715, dtype: int64
#
# Column Name: V1
# Has null values: False
# Amount of null values: 0
# Values - Count
#  2.062500    131
#  2.042969    111
#  2.052734    105
#  2.054688    104
#  2.041016    104
#             ...
# -5.753906      1
# -0.011353      1
# -0.034668      1
#  0.008911      1
#  0.015625      1
# Name: V1, Length: 10899, dtype: int64
#
# Column Name: V2
# Has null values: False
# Amount of null values: 0
# Values - Count
# 1.109375    29
# 1.041016    28
# 1.117188    27
# 1.094727    27
# 1.163086    27
#             ..
# 4.687500     1
# 0.013649     1
# 2.437500     1
# 0.047607     1
# 0.027832     1
# Name: V2, Length: 14654, dtype: int64
#
# Column Name: V3
# ...

# %%
check_null_values(test_hidden_df)
# Out:
# Column Name: Time
# Has null values: False
# Amount of null values: 0
# Values - Count
# 64947.0     7
# 163152.0    7
# 68780.0     7
# 142583.0    6
# 60988.0     5
#            ..
# 141363.0    1
# 92436.0     1
# 128025.0    1
# 74404.0     1
# 154020.0    1
# Name: Time, Length: 46715, dtype: int64
#
# Column Name: V1
# Has null values: False
# Amount of null values: 0
# Values - Count
#  2.062500    131
#  2.042969    111
#  2.052734    105
#  2.054688    104
#  2.041016    104
#             ...
# -5.753906      1
# -0.011353      1
# -0.034668      1
#  0.008911      1
#  0.015625      1
# Name: V1, Length: 10899, dtype: int64
#
# Column Name: V2
# Has null values: False
# Amount of null values: 0
# Values - Count
# 1.109375    29
# 1.041016    28
# 1.117188    27
# 1.094727    27
# 1.163086    27
#             ..
# 4.687500     1
# 0.013649     1
# 2.437500     1
# 0.047607     1
# 0.027832     1
# Name: V2, Length: 14654, dtype: int64
#
# Column Name: V3
# ...

# %%
print('Shape of dataframe:')
print('Train_df:', train_df.shape)
print('Test_df:', test_df.shape)
print('Test_hidden_df:', test_hidden_df.shape)
# Out:
# Shape of dataframe:
# Train_df: (454902, 31)
# Test_df: (56962, 30)
# Test_hidden_df: (56962, 31)

# %%
val_df = test_hidden_df
del(test_hidden_df)
val_df.head()
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0  113050.0  0.114685  0.796387 -0.149536 -0.823242  0.878906 -0.553223
# 1   26667.0 -0.039307  0.495850 -0.811035  0.546875  1.986328  4.386719
# 2  159519.0  2.275391 -1.531250 -1.021484 -1.602539 -1.220703 -0.462402
# 3  137545.0  1.940430 -0.357666 -1.210938  0.382568  0.050812 -0.171265
# 4   63369.0  1.081055 -0.502441  1.076172 -0.543457 -1.472656 -1.065430
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.939453 -0.108521  0.111145  ... -0.335693 -0.807617 -0.055939 -1.025391
# 1 -1.344727 -1.744141 -0.562988  ... -1.376953 -0.072205 -0.197632  1.014648
# 2 -1.196289 -0.147095 -0.950195  ... -0.193237 -0.103516  0.151001 -0.811035
# 3 -0.109131 -0.002115  0.869141  ...  0.157959  0.650391  0.034210  0.739746
# 4 -0.443115 -0.143433  1.660156  ...  0.224121  0.821289 -0.137207  0.986328
#
#         V25       V26       V27       V28     Amount  Class
# ...

# %% [markdown]
# <a id='xtract'></a>
# ### FEATURES AND LABEL EXTRACTION

# %% [markdown]
# <a href='#top'>TOP</a>
# <br>
# <br>
# <a href='#TOC'>Table of Content</a>

# %%
Ytrain = train_df['Class']
Xtrain = train_df.drop(columns=['Class'])
Yval = val_df['Class']
Xval = val_df.drop(columns=['Class'])
Xtest = test_df
print('Ytrain:', Ytrain.shape)
print('Xtain:', Xtrain.shape)
print('Yval:', Yval.shape)
print('Xval:', Xval.shape)
print('Xtest:', Xtest.shape)
Xtrain_cols = Xtrain.columns
Xval_cols = Xval.columns
Xtest_cols = Xtest.columns
# Out:
# Ytrain: (454902,)
# Xtain: (454902, 30)
# Yval: (56962,)
# Xval: (56962, 30)
# Xtest: (56962, 30)

# %% [markdown]
# <a id='preproc'></a>
# ### PREPROCESSING

# %% [markdown]
# <a href='#top'>TOP</a>
# <br>
# <br>
# <a href='#TOC'>Table of Content</a>

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(Xtrain, Ytrain)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
Xtrain = pd.DataFrame(data=scaler.transform(Xtrain), columns=Xtrain_cols)
Xval = pd.DataFrame(data=scaler.transform(Xval), columns=Xval_cols)
Xtest = pd.DataFrame(data=scaler.transform(Xtest), columns=Xtest_cols)

# %%
import pickle
pickle.dump(scaler, open('./scaler.data', 'wb'))
pickle.dump(Ytrain, open('./Ytrain.data', 'wb'))
pickle.dump(Xtrain, open('./Xtrain.data', 'wb'))
pickle.dump(Yval, open('./Yval.data', 'wb'))
pickle.dump(Xval, open('./Xval.data', 'wb'))
pickle.dump(Xtest, open('./Xtest.data', 'wb'))
del(train_df)
del(test_df)
del(val_df)

# %% [markdown]
# <a id='eval_func'></a>
# ### EVALUATION FUNCTION

# %% [markdown]
# <a href='#top'>TOP</a>
# <br>
# <br>
# <a href='#TOC'>Table of Content</a>

# %%
from sklearn.metrics import accuracy_score, log_loss, roc_auc_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, mean_squared_error

# %%
def print_stats(Ytrain, Yval, Ytrain_, Yval_):
    print('Training Results:')
    print('=================================================')
    print('Accuracy Score:')
    print(accuracy_score(Ytrain, Ytrain_))
    print()
    print('Mean Squared Error:')
    print(mean_squared_error(Ytrain, Ytrain_))
    print()
    print('Log Loss:')
    print(log_loss(Ytrain, Ytrain_))
    print()
    print('ROC_AUC Score:')
    print(roc_auc_score(Ytrain, Ytrain_))
    print()
    print('Precision Score:')
    print(precision_score(Ytrain, Ytrain_))
    print()
    print('Recall Score:')
    print(recall_score(Ytrain, Ytrain_))
    print()
    print('F1 Score:')
    print(f1_score(Ytrain, Ytrain_))
    print()
    print('Confusion Matrix:')
    print(confusion_matrix(Ytrain, Ytrain_))
    print()
    print('Classification Report:')
    print(classification_report(Ytrain, Ytrain_))
    print()
    print('Validation Results:')
    print('=================================================')
    print('Accuracy Score:')
    print(accuracy_score(Yval, Yval_))
    print()
    print('Mean Squared Error:')
    print(mean_squared_error(Yval, Yval_))
    print()
    print('Log Loss:')
    print(log_loss(Yval, Yval_))
    print()
    print('ROC_AUC Score:')
    print(roc_auc_score(Yval, Yval_))
    print()
    print('Precision Score:')
    print(precision_score(Yval, Yval_))
    print()
    print('Recall Score:')
    print(recall_score(Yval, Yval_))
    print()
    print('F1 Score:')
    print(f1_score(Yval, Yval_))
    print()
    print('Confusion Matrix:')
    print(confusion_matrix(Yval, Yval_))
    print()
    print('Classification Report:')
    print(classification_report(Yval, Yval_))
    print()

# %% [markdown]
# <a id='models'></a>
# ### MODELS

# %% [markdown]
# <a id='lr'></a>
# ### LOGISTIC REGRESSION

# %% [markdown]
# <a href='#top'>TOP</a>
# <br>
# <br>
# <a href='#TOC'>Table of Content</a>

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()
clf.fit(Xtrain, Ytrain)
# Out:
# C:\Anaconda3\envs\dsmldl\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
pickle.dump(clf, open('./models/clf_LR.model', 'wb'))

# %%
Ytrain_ = clf.predict(Xtrain)
Yval_ = clf.predict(Xval)

# %%
print_stats(Ytrain, Yval, Ytrain_, Yval_)
# Out:
# Training Results:
# ...
# Accuracy Score:
# 0.9521545299866785
#
# Mean Squared Error:
# 0.04784547001332155
#
# Log Loss:
# 1.6525319299911279
#
# ROC_AUC Score:
# 0.9521545299866785
#
# Precision Score:
# 0.978963301043219
#
# Recall Score:
# 0.924168282399286
#
# F1 Score:
# 0.9507769618541243
#
# Confusion Matrix:
# [[222934   4517]
#  [ 17248 210203]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95    227451
#            1       0.98      0.92      0.95    227451
#
#     accuracy                           0.95    454902
#    macro avg       0.95      0.95      0.95    454902
# weighted avg       0.95      0.95      0.95    454902
#
#
# Validation Results:
# ...
# Accuracy Score:
# 0.9796882131947614
#
# Mean Squared Error:
# 0.02031178680523858
#
# Log Loss:
# 0.7015603354511654
#
# ROC_AUC Score:
# 0.9287076289435302
#
# Precision Score:
# 0.06986190089358245
#
# Recall Score:
# 0.8775510204081632
#
# ...

# %% [markdown]
# <a id='naive'></a>
# ### GAUSSIAN NAIVE BAYES

# %% [markdown]
# <a href='#top'>TOP</a>
# <br>
# <br>
# <a href='#TOC'>Table of Content</a>

# %%
from sklearn.naive_bayes import GaussianNB

# %%
clf = GaussianNB()

# %%
clf.fit(Xtrain, Ytrain)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
pickle.dump(clf, open('./models/clf_NB.model', 'wb'))

# %%
Ytrain_ = clf.predict(Xtrain)
Yval_ = clf.predict(Xval)

# %%
print_stats(Ytrain, Yval, Ytrain_, Yval_)
# Out:
# Training Results:
# ...
# Accuracy Score:
# 0.9212159981710346
#
# Mean Squared Error:
# 0.07878400182896536
#
# Log Loss:
# 2.7211133300283024
#
# ROC_AUC Score:
# 0.9212159981710346
#
# Precision Score:
# 0.9711616012589751
#
# Recall Score:
# 0.8682133734298816
#
# F1 Score:
# 0.9168065256702207
#
# Confusion Matrix:
# [[221587   5864]
#  [ 29975 197476]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.93    227451
#            1       0.97      0.87      0.92    227451
#
#     accuracy                           0.92    454902
#    macro avg       0.93      0.92      0.92    454902
# weighted avg       0.93      0.92      0.92    454902
#
#
# Validation Results:
# ...
# Accuracy Score:
# 0.9737193216530319
#
# Mean Squared Error:
# 0.026280678346968154
#
# Log Loss:
# 0.9077232342224745
#
# ROC_AUC Score:
# 0.8951585523066853
#
# Precision Score:
# 0.05131494547787043
#
# Recall Score:
# 0.8163265306122449
#
# ...

# %% [markdown]
# <a id='lda'></a>
# ### LINEAR DISCRIMINANT ANALYSIS

# %% [markdown]
# <a href='#top'>TOP</a>
# <br>
# <br>
# <a href='#TOC'>Table of Content</a>

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
clf = LinearDiscriminantAnalysis()

# %%
clf.fit(Xtrain, Ytrain)

# %%
pickle.dump(clf, open('./models/clf_LDA.model', 'wb'))

# %%
Ytrain_ = clf.predict(Xtrain)
Yval_ = clf.predict(Xval)

# %%
print_stats(Ytrain, Yval, Ytrain_, Yval_)

# %% [markdown]
# <a id='svm'></a>
# ### SUPPORT VECTOR MACHINE

# %% [markdown]
# <a href='#top'>TOP</a>
# <br>
# <br>
# <a href='#TOC'>Table of Content</a>

# %%
from sklearn.svm import SVC

# %%
clf = SVC(verbose=True)

# %%
clf.fit(Xtrain, Ytrain)

# %%
pickle.dump(clf, open('./models/clf_SVM.model', 'wb'))

# %%
Ytrain_ = clf.predict(Xtrain)
Yval_ = clf.predict(Xval)

# %%
print_stats(Ytain, Yval, Ytrain_, Yval_)

# %% [markdown]
# <a id='rfc'></a>
# ### RANDOM FOREST CLASSIFIER

# %% [markdown]
# <a href='#top'>TOP</a>
# <br>
# <br>
# <a href='#TOC'>Table of Content</a>

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier(n_estimators=300, criterion='entropy', n_jobs=-1, verbose=1)

# %%
clf.fit(Xtrain, Ytrain)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed:   20.3s finished
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=150,
#                        n_jobs=-1, oob_score=False, random_state=None, verbose=1,
#                        warm_start=False)

# %%
pickle.dump(clf, open('./models/clf_RFC.model', 'wb'))

# %%
Ytrain_ = clf.predict(Xtrain)
Yval_ = clf.predict(Xval)
# Out:
# [Parallel(n_jobs=32)]: Using backend ThreadingBackend with 32 concurrent workers.
# [Parallel(n_jobs=32)]: Done 150 out of 150 | elapsed:    1.2s finished
# [Parallel(n_jobs=32)]: Using backend ThreadingBackend with 32 concurrent workers.
# [Parallel(n_jobs=32)]: Done 150 out of 150 | elapsed:    0.1s finished

# %%
print_stats(Ytrain, Yval, Ytrain_, Yval_)
# Out:
# Training Results:
# ...
# Accuracy Score:
# 1.0
#
# Mean Squared Error:
# 0.0
#
# Log Loss:
# 9.99200722162641e-16
#
# ROC_AUC Score:
# 1.0
#
# Precision Score:
# 1.0
#
# Recall Score:
# 1.0
#
# F1 Score:
# 1.0
#
# Confusion Matrix:
# [[227451      0]
#  [     0 227451]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227451
#            1       1.00      1.00      1.00    227451
#
#     accuracy                           1.00    454902
#    macro avg       1.00      1.00      1.00    454902
# weighted avg       1.00      1.00      1.00    454902
#
#
# Validation Results:
# ...
# Accuracy Score:
# 0.9995611109160493
#
# Mean Squared Error:
# 0.00043888908395070395
#
# Log Loss:
# 0.015158734044891584
#
# ROC_AUC Score:
# 0.8877287233126226
#
# Precision Score:
# 0.9620253164556962
#
# Recall Score:
# 0.7755102040816326
#
# F1 Score:
# 0.8587570621468926
#
# Confusion Matrix:
# [[56861     3]
#  [   22    76]]
# ...

# %% [markdown]
# <a id='xgb'></a>
# ### XGBOOST CLASSIFIER

# %% [markdown]
# <a href='#top'>TOP</a>
# <br>
# <br>
# <a href='#TOC'>Table of Content</a>

# %%
from xgboost import XGBClassifier

# %%
clf = XGBClassifier(max_depth=60, n_estimators=300, n_jobs=-1, verbosity=1)

# %%
clf.fit(Xtrain, Ytrain)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=50,
#               min_child_weight=1, missing=None, n_estimators=150, n_jobs=-1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
pickle.dump(clf, open('./models/clf_XGBC.model', 'wb'))

# %%
Ytrain_ = clf.predict(Xtrain)
Yval_ = clf.predict(Xval)

# %%
print_stats(Ytrain, Yval, Ytrain_, Yval_)
# Out:
# Training Results:
# ...
# Accuracy Score:
# 1.0
#
# Mean Squared Error:
# 0.0
#
# Log Loss:
# 9.99200722162641e-16
#
# ROC_AUC Score:
# 1.0
#
# Precision Score:
# 1.0
#
# Recall Score:
# 1.0
#
# F1 Score:
# 1.0
#
# Confusion Matrix:
# [[227451      0]
#  [     0 227451]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227451
#            1       1.00      1.00      1.00    227451
#
#     accuracy                           1.00    454902
#    macro avg       1.00      1.00      1.00    454902
# weighted avg       1.00      1.00      1.00    454902
#
#
# Validation Results:
# ...
# Accuracy Score:
# 0.999420666409185
#
# Mean Squared Error:
# 0.0005793335908149292
#
# Log Loss:
# 0.020009627762435332
#
# ROC_AUC Score:
# 0.8876583800374398
#
# Precision Score:
# 0.8735632183908046
#
# Recall Score:
# 0.7755102040816326
#
# F1 Score:
# 0.8216216216216217
#
# Confusion Matrix:
# [[56853    11]
#  [   22    76]]
#
# ...

# %% [markdown]
# <a id='lightgbm'></a>
# ### LIGHT GBM CLASSIFIER

# %% [markdown]
# <a href='#top'>TOP</a>
# <br>
# <br>
# <a href='#TOC'>Table of Content</a>

# %%
from lightgbm import LGBMClassifier

# %%
clf = LGBMClassifier(n_estimators=300, num_leaves=300, objective='cross_entropy', silent=False)

# %%
clf.fit(Xtrain, Ytrain)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=150, n_jobs=-1, num_leaves=150,
#                objective='cross_entropy', random_state=None, reg_alpha=0.0,
#                reg_lambda=0.0, silent=False, subsample=1.0,
#                subsample_for_bin=200000, subsample_freq=0)

# %%
pickle.dump(clf, open('./models/clf_LGBMC.model', 'wb'))

# %%
Ytrain_ = clf.predict(Xtrain)
Yval_ = clf.predict(Xval)

# %%
print_stats(Ytrain, Yval, Ytrain_, Yval_)
# Out:
# Training Results:
# ...
# Accuracy Score:
# 1.0
#
# Mean Squared Error:
# 0.0
#
# Log Loss:
# 9.99200722162641e-16
#
# ROC_AUC Score:
# 1.0
#
# Precision Score:
# 1.0
#
# Recall Score:
# 1.0
#
# F1 Score:
# 1.0
#
# Confusion Matrix:
# [[227451      0]
#  [     0 227451]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227451
#            1       1.00      1.00      1.00    227451
#
#     accuracy                           1.00    454902
#    macro avg       1.00      1.00      1.00    454902
# weighted avg       1.00      1.00      1.00    454902
#
#
# Validation Results:
# ...
# Accuracy Score:
# 0.9994908886626171
#
# Mean Squared Error:
# 0.0005091113373828166
#
# Log Loss:
# 0.017584166866280115
#
# ROC_AUC Score:
# 0.8826003037681027
#
# Precision Score:
# 0.9259259259259259
#
# Recall Score:
# 0.7653061224489796
#
# F1 Score:
# 0.8379888268156425
#
# Confusion Matrix:
# [[56858     6]
#  [   23    75]]
#
# ...

# %% [markdown]
# <a id='ann'></a>
# ### ANN CLASSIFIER

# %% [markdown]
# <a href='#top'>TOP</a>
# <br>
# <br>
# <a href='#TOC'>Table of Content</a>

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
# Out:
# Using TensorFlow backend.

# %%
early_stop = EarlyStopping(patience=15, verbose=1)
reduce_lr = ReduceLROnPlateau(patience=5, cooldown=5, verbose=1)

callbacks = [early_stop, reduce_lr]

# %%
clf = Sequential()

clf.add(Dense(units=20, activation='relu', input_dim=30))
clf.add(Dropout(rate=0.1))

clf.add(Dense(units=20, activation='relu'))
clf.add(Dropout(rate=0.1))

clf.add(Dense(units=20, activation='relu'))
clf.add(Dropout(rate=0.1))

clf.add(Dense(units=1, activation='sigmoid'))

clf.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
clf.summary()
# Out:
# WARNING:tensorflow:From C:\Anaconda3\envs\dsmldl\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Anaconda3\envs\dsmldl\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 20)                620
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20)                0
# ...

# %%
history = clf.fit(Xtrain, Ytrain, epochs=150, batch_size=64, validation_split=0.2, callbacks=callbacks, verbose=1)
# Out:
# WARNING:tensorflow:From C:\Anaconda3\envs\dsmldl\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 409411 samples, validate on 45491 samples
# Epoch 1/150
# 409411/409411 [==============================] - 19s 45us/step - loss: 0.1688 - acc: 0.9398 - val_loss: 0.1583 - val_acc: 0.9216
# Epoch 2/150
# 409411/409411 [==============================] - 17s 42us/step - loss: 0.1303 - acc: 0.9511 - val_loss: 0.1551 - val_acc: 0.9253
# Epoch 3/150
# 409411/409411 [==============================] - 17s 42us/step - loss: 0.1131 - acc: 0.9563 - val_loss: 0.1298 - val_acc: 0.9368
# Epoch 4/150
# 409411/409411 [==============================] - 17s 42us/step - loss: 0.1018 - acc: 0.9613 - val_loss: 0.1350 - val_acc: 0.9310
# Epoch 5/150
# ...

# %%
clf.save('./models/model_ANN_01.h5')

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(12,16))
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
plt.savefig('./dump/ANN_Accuracy_plot.png')

# %%
# Plot training & validation loss values
plt.figure(figsize=(12,16))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
plt.savefig('./dump/ANN_Loss_plot.png')

# %%
Ytrain_ = clf.predict(Xtrain) > 0.5
Yval_ = clf.predict(Xval) > 0.5

# %%
print_stats(Ytrain, Yval, Ytrain_, Yval_)
# Out:
# Training Results:
# ...
# Accuracy Score:
# 0.9967113795938466
#
# Mean Squared Error:
# 0.0032886204061534133
#
# Log Loss:
# 0.11358755442829967
#
# ROC_AUC Score:
# 0.9967113795938466
#
# Precision Score:
# 0.9934657366115301
#
# Recall Score:
# 1.0
#
# F1 Score:
# 0.9967221591680946
#
# Confusion Matrix:
# [[225955   1496]
#  [     0 227451]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00    227451
#            1       0.99      1.00      1.00    227451
#
#     accuracy                           1.00    454902
#    macro avg       1.00      1.00      1.00    454902
# weighted avg       1.00      1.00      1.00    454902
#
#
# Validation Results:
# ...
# Accuracy Score:
# 0.9929953302201467
#
# Mean Squared Error:
# 0.007004669779853236
#
# Log Loss:
# 0.24193805745221186
#
# ROC_AUC Score:
# 0.8997199189186086
#
# Precision Score:
# 0.1721132897603486
#
# Recall Score:
# 0.8061224489795918
#
# F1 Score:
# ...

# %% [markdown]
# <a id='mod_ana'></a>
# ### ANN MODEL ANALYSIS

# %% [markdown]
# <a href='#top'>TOP</a>
# <br>
# <br>
# <a href='#TOC'>Table of Content</a>

# %%
from keras.models import load_model

# %%
clf = load_model('./models/model_ANN_01.h5')

# %%
def map_cm(x, y):
    if x == y & y == 1:
        return 'TP'
    if x != y & y == 1:
        return 'FP'
    if x == y & y == 0:
        return 'TN'
    if x != y & y == 0:
        return 'FN'

# %%
Ytrain_ = clf.predict(Xtrain)
Yval_ = clf.predict(Xval)
df_pred_ytrain = pd.DataFrame(data=Ytrain_,columns=['Proba'] )
df_pred_yval = pd.DataFrame(data=Yval_, columns=['Proba'])
df_pred_ytrain['Actual'] = Ytrain.values
df_pred_ytrain['Prediction'] = df_pred_ytrain['Proba'].map(lambda x: 1 if x > 0.5 else 0)
df_pred_ytrain['Remarks'] = df_pred_ytrain[['Actual', 'Prediction']].apply(lambda x: map_cm(x['Actual'], x['Prediction']), axis=1)
df_pred_yval['Actual'] = Yval.values
df_pred_yval['Prediction'] = df_pred_yval['Proba'].apply(lambda x: 1 if x > 0.5 else 0)
df_pred_yval['Remarks'] = df_pred_yval[['Actual', 'Prediction']].apply(lambda x: map_cm(x['Actual'], x['Prediction']), axis=1)

# %%
display(df_pred_ytrain.head())
display(df_pred_yval.head())
display(df_pred_yval['Remarks'].value_counts())
display(df_pred_ytrain['Remarks'].value_counts())

# %%
val_view = test_hidden_df.join(df_pred_yval)
val_view = val_view.drop(columns=['Proba', 'Actual', 'Prediction', 'Class'])
display(val_view)

# %%
plt.figure(figsize=(20, 32))
for index, column in enumerate(val_view.drop(columns=['Remarks']).columns):
    plt.subplot(8, 4, index+1)
    sns.barplot(x=column, y='Remarks', data=val_view)
plt.savefig('./dump/val_view_sns_barplot.png')

# %%
plt.figure(figsize=(20, 32))
for index, column in enumerate(val_view.drop(columns=['Remarks']).columns):
    plt.subplot(8, 4, index+1)
    sns.scatterplot(x=column, y='Remarks', data=val_view)
plt.savefig('./dump/val_view_sns_scatterplot.png')

# %% [markdown]
# <a id='clf_voting'></a>
# ### CLASSIFIER VOTING

# %% [markdown]
# <a href='#top'>TOP</a>
# <br>
# <br>
# <a href='#TOC'>Table of Content</a>

# %%
model_files = os.listdir(MODELS_DIR)
model_files

# %%
ml_models = []
ann_models = []
for i, model in enumerate(model_files):
    if '.model' in model:
        clf = pickle.load(open(MODELS_DIR + '/' + model, 'rb'))
        ml_models.append(clf)
    else:
        clf = load_model('./models/model_ANN_01.h5')
        ann_models.append(clf)

# %%
train_voting_df = pd.DataFrame(data=Ytrain, columns=['Class'])
val_voting_df = pd.DataFrame(data=Yval, columns=['Class'])
test_voting_df = pd.DataFrame(data=np.random.random(Xtest.shape[0]), columns=['Class'])
display(train_voting_df)
display(val_voting_df)
display(test_voting_df)

# %%
for i, clf in enumerate(ml_models):
    model_name= 'clf_ml' + '_' + str(i)
    Ytrain_ = clf.predict(Xtrain)
    Yval_ = clf.predict(Xval)
    Ytest_ = clf.predict(Xtest)
    print(clf)
    print_stats(Ytrain, Yval, Ytrain_, Yval_)
    train_voting_df[model_name + '_' + 'Prediction'] = Ytrain_
    val_voting_df[model_name + '_' + 'Prediction'] = Yval_
    test_voting_df[model_name + '_' + 'Prediction'] = Ytest_
display(train_voting_df.head())
display(val_voting_df.head())
display(test_voting_df.head())

# %%
for i, clf in enumerate(ann_models):
    model_name= 'clf_ann' + '_' + str(i)
    Ytrain_ = clf.predict(Xtrain) > 0.5
    Yval_ = clf.predict(Xval) > 0.5
    Ytest_ = clf.predict(Xtest) > 0.5
    print(clf)
    print_stats(Ytrain, Yval, Ytrain_, Yval_)
    train_voting_df[model_name + '_' + 'Prediction'] = Ytrain_
    val_voting_df[model_name + '_' + 'Prediction'] = Yval_
    test_voting_df[model_name + '_' + 'Prediction'] = Ytest_
display(train_voting_df.head())
display(val_voting_df.head())
display(test_voting_df.head())

# %%
train_voting_df['clf_ann_0_Prediction'] = train_voting_df['clf_ann_0_Prediction'].map(lambda x: 0 if x == False else 1)
val_voting_df['clf_ann_0_Prediction'] = val_voting_df['clf_ann_0_Prediction'].map(lambda x: 0 if x == False else 1)
test_voting_df['clf_ann_0_Prediction'] = test_voting_df['clf_ann_0_Prediction'].map(lambda x: 0 if x == False else 1)
display(train_voting_df.head())
display(val_voting_df.head())
display(test_voting_df.head())

# %%
train_voting_df['Voting_Sum'] = train_voting_df.iloc[:, 1:7].sum(axis=1)
train_voting_df.head()

# %%
plt.figure(figsize=(12, 16))
sns.distplot(train_voting_df['Voting_Sum'])
plt.savefig('./dump/train_voting_df_sns_distplot.png')

# %%
plt.figure(figsize=(12, 16))
sns.countplot(x='Voting_Sum', data=train_voting_df[['Class', 'Voting_Sum']], hue='Class')
plt.savefig('./dump/train_voting_df_sns_countplot.png')

# %%
val_voting_df['Voting_Sum'] = val_voting_df.iloc[:, 1:7].sum(axis=1)
val_voting_df.head()

# %%
plt.figure(figsize=(12, 16))
sns.distplot(val_voting_df['Voting_Sum'])
plt.savefig('./dump/val_voting_df_sns_distplot.png')

# %%
sns.countplot(x='Voting_Sum', data=val_voting_df[['Class', 'Voting_Sum']], hue='Class')
plt.figure(figsize=(12, 16))
plt.savefig('./dump/val_voting_df_sns_countplot.png')

# %%
test_voting_df['Voting_Sum'] = test_voting_df.iloc[:, 1:7].sum(axis=1)
test_voting_df.head()

# %%
plt.figure(figsize=(12, 16))
sns.distplot(test_voting_df['Voting_Sum'])
plt.savefig('./dump/test_voting_df_sns_distplot.png')

# %%
test_voting_df['Voting_Sum'].value_counts()
